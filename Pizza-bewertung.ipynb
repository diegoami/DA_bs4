# %%
url='https://pizza.de/lieferservice/berlin/restaurant-yoko-sushi-berlin-martin-luther-str-410/9647/'

# %%
import requests
r = requests.get(url)

# %%
r.text
# Out:
# '<!doctype html>\n<html class="no-js  no-webp" lang="de"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><title>Yoko Sushi, Berlin, Martin-Luther-Straße 41</title><meta name="description" content="Yoko Sushi Martin-Luther-Straße in Berlin. Bestell bei Yoko Sushi online &amp; lass es dir per Lieferservice bringen."/><meta name="robots" content="noodp"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><script>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"df352a0296","applicationID":"42027937","applicationTime":873.573812,"transactionName":"b1RbN0VSDUNSUEYLXlYeegxZRxFfX19XEB4XXVAGUVYRQ1ZBRAtSXR4DAF5HGmNfRlVNQ11CTQJCQQJeRxsfWENdQk0CQkECXkdgXhdWER4RWUVWEERSRkADX0x4XUoYHCR1Zw==","queueTime":0,"ttGuid":"b05d7c76a184b8","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"VQMEU1JWARAEVlFQAAgEUQ=="};window.NREUM||
# ...
