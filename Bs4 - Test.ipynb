# %%
import requests

# %%
url = 'https://api.github.com/events'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '[{"id":"6608112716","type":"PushEvent","actor":{"id":11405600,"login":"sadelokiki","display_login":"sadelokiki","gravatar_id":"","url":"https://api.github.com/users/sadelokiki","avatar_url":"https://avatars.githubusercontent.com/u/11405600?"},"repo":{"id":99148438,"name":"chanzuckerberg/idseq-web","url":"https://api.github.com/repos/chanzuckerberg/idseq-web"},"payload":{"push_id":1994354657,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"4bb7db6b09f2ca13f03d4559442de7616b3a16d5","before":"906a28ab06ab280193a8fdf95812b730896172e3","commits":[{"sha":"4bb7db6b09f2ca13f03d4559442de7616b3a16d5","author":{"email":"susan.adelokiki@andela.co","name":"sadelokiki"},"message":"Feature/enable cors (#64)\\n\\n* Enable cors\\r\\n\\r\\n* Refactor config hash syntax","distinct":true,"url":"https://api.github.com/repos/chanzuckerberg/idseq-web/commits/4bb7db6b09f2ca13f03d4559442de7616b3a16d5"}]},"public":true,"created_at":"2017-09-19T09:42:47Z","org":{"id":19917299,"login":"chanzuckerbe
# ...

# %%
import lxml

# %%
import bs4

# %%
r.text[0]
# Out:
# '['

# %%
import json

# %%
rjs = r.json()

# %%
rjs[0]
# Out:
# {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/11405600?',
#   'display_login': 'sadelokiki',
#   'gravatar_id': '',
#   'id': 11405600,
#   'login': 'sadelokiki',
#   'url': 'https://api.github.com/users/sadelokiki'},
#  'created_at': '2017-09-19T09:42:47Z',
#  'id': '6608112716',
#  'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/19917299?',
#   'gravatar_id': '',
#   'id': 19917299,
#   'login': 'chanzuckerberg',
#   'url': 'https://api.github.com/orgs/chanzuckerberg'},
#  'payload': {'before': '906a28ab06ab280193a8fdf95812b730896172e3',
#   'commits': [{'author': {'email': 'susan.adelokiki@andela.co',
#      'name': 'sadelokiki'},
#     'distinct': True,
#     'message': 'Feature/enable cors (#64)\n\n* Enable cors\r\n\r\n* Refactor config hash syntax',
#     'sha': '4bb7db6b09f2ca13f03d4559442de7616b3a16d5',
#     'url': 'https://api.github.com/repos/chanzuckerberg/idseq-web/commits/4bb7db6b09f2ca13f03d4559442de7616b3a16d5'}],
# ...

# %%
rjs[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %%
[rj for rj in rjs]
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/11405600?',
#    'display_login': 'sadelokiki',
#    'gravatar_id': '',
#    'id': 11405600,
#    'login': 'sadelokiki',
#    'url': 'https://api.github.com/users/sadelokiki'},
#   'created_at': '2017-09-19T09:42:47Z',
#   'id': '6608112716',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/19917299?',
#    'gravatar_id': '',
#    'id': 19917299,
#    'login': 'chanzuckerberg',
#    'url': 'https://api.github.com/orgs/chanzuckerberg'},
#   'payload': {'before': '906a28ab06ab280193a8fdf95812b730896172e3',
#    'commits': [{'author': {'email': 'susan.adelokiki@andela.co',
#       'name': 'sadelokiki'},
#      'distinct': True,
#      'message': 'Feature/enable cors (#64)\n\n* Enable cors\r\n\r\n* Refactor config hash syntax',
#      'sha': '4bb7db6b09f2ca13f03d4559442de7616b3a16d5',
# ...
